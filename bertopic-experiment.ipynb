# %%
# !pip install -q sentence-transformers pylatexenc bertopic hdbscan octis
# Out:
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the '/home/paul/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np
from numpy.random import default_rng
import transformers
import pandas as pd
from tqdm.notebook import tqdm
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import torch
import umap
import optuna
import hdbscan
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
from octis.evaluation_metrics.diversity_metrics import TopicDiversity
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

from pylatexenc.latex2text import LatexNodes2Text

# %%
def split_data(data, train_size=5000, optim_size=6000):
    test_size = len(data) - train_size - optim_size
    rng = np.random.default_rng(49)
    labels = np.array(['train'] * train_size + ['val'] * optim_size + ['test'] * test_size)
    rng.shuffle(labels)
    return labels

torch.manual_seed(42)
np.random.seed(42)
torch.manual_seed(42)
transformers.set_seed(42)
tqdm.pandas()
docs_df = pd.read_csv('to_use.csv')
df = docs_df.sample(25000, random_state=42)
df['type_set'] = split_data(df)
np.unique(df['type_set'], return_counts=True)
# Out:
# <ipython-input-3-4fee462b3189>:13: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   docs_df = pd.read_csv('to_use.csv')
# (array(['test', 'train', 'val'], dtype=object), array([14000,  5000,  6000]))

# %%
def clean_abstract(txt, stp_wrds):
    txt = txt.lower()
    try:
        txt = LatexNodes2Text().latex_to_text(txt)
    except:
        txt = txt.lower()
    sup = word_tokenize(txt, language="english")
    lemmatizer = WordNetLemmatizer()
    sup = [lemmatizer.lemmatize(word) for word in sup]
    ret = []
    for el in sup:
        el.replace('\\', '')
        if el not in stp_wrds and el not in string.punctuation:
            ret.append(el)
    return ' '.join(ret)

# %%
stop_words = nltk.corpus.stopwords.words("english")
stop_words += ['we', 'paper', 'new', 'article', "''", "``", "”", 'et', 'al', 'study', 'state', 'of', 'the', 'art']
cleaned_abstract = df['abstract'].progress_apply(clean_abstract, args=[stop_words])
df['abstract_uncleaned'] = df['abstract'].copy()
df['abstract'] = cleaned_abstract
data_val = df[df['type_set'] == 'val']['abstract'].tolist()
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]

# %%
data_test = df[df['type_set'] == 'test']['abstract'].tolist()

# %%
data_val[0]
# Out:
# 'convergence stationarity random walk dynamic random digraph given degree sequence digraph undergo full regeneration independent geometrically distributed random time interval parameter α. relaxation stationarity result competition regeneration mixing static digraph number vertex n tends infinity parameter α tends zero find three scenario according whether αlog n converges zero infinity finite positive value limit zero relaxation stationarity occurs two separate stage first due mixing static digraph second due regeneration limit infinite enough time static digraph mix relaxation stationarity dictated regeneration finally limit finite positive value find mixed behaviour interpolating two extreme crucial ingredient analysis control suitable approximation unknown stationary distribution'

# %%
def get_crps(txts: list):
    ret = []
    for el in txts:
        ret.append(el.split())
    return ret


def get_dict(data):
    return dict(zip(data['Topic'].tolist(), [el.split('_')[1:] for el in data['Name'].tolist()]))


def transform_topics(lst, dct):
    ret = []
    for el in lst:
        ret.append(dct[el])
    return ret


def compute_coherence(topic_model, name_c, data, topics_, topn):
    cleaned_docs = topic_model._preprocess_text(data)

    # Extract vectorizer and tokenizer from BERTopic
    vectorizer = topic_model.vectorizer_model
    tokenizer = vectorizer.build_tokenizer()

    # Extract features for Topic Coherence evaluation
    words = vectorizer.get_feature_names()
    tokens = [tokenizer(doc) for doc in cleaned_docs]
    dictionary = corpora.Dictionary(tokens)
    corpus = [dictionary.doc2bow(token) for token in tokens]
    topic_words = [[words for words, _ in topic_model.get_topic(topic) if words!='']
                   for topic in range(len(set(topics_))-1)]

    # Evaluate
    coherence_model = CoherenceModel(topics=topic_words,
                                     texts=tokens,
                                     corpus=corpus,
                                     dictionary=dictionary,
                                     coherence=name_c, topn=topn)
    coherence = coherence_model.get_coherence()
    return coherence


@torch.no_grad()
def compute_metrics(topics_, topic_model_, data, top_k=5):
    try:
        output = {'topics' : [[words for words, _ in topic_model.get_topic(topic)]for topic in range(len(set(topics_[0]))-1)]}
        topic_diversity = TopicDiversity(topk=top_k)
        topic_diversity_score = topic_diversity.score(output)
    except:
        topic_diversity_score = None

    npmi_score = compute_coherence(topic_model_,'c_npmi', data, topics_[0], top_k)
    cv_score = compute_coherence(topic_model_,'c_v', data, topics_[0], top_k)

    return topic_diversity_score, npmi_score, cv_score

# %%
lst_models = ['johngiorgi/declutr-base', 'google/electra-base-discriminator', 'sentence-transformers/all-distilroberta-v1',
              'microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract', 'all-mpnet-base-v2']
scores_untrained = []
with torch.no_grad():
    for md in lst_models:
        sentence_model = SentenceTransformer(md, device="cuda")
        topic_model = BERTopic(embedding_model=sentence_model)
        topics = topic_model.fit_transform(np.array(data_test))
        scores_untrained.append(compute_metrics(topics, topic_model, np.array(data_test)))
print(scores_untrained)
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.44k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/548 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/johngiorgi_declutr-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Downloading:   0%|          | 0.00/390 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/27.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/google_electra-base-discriminator were not used when initializing ElectraModel: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/737 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.86k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/653 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/329M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/333 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.07k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.94k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/225k [00:00<?, ?B/s]
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/microsoft_BiomedNLP-PubMedBERT-base-uncased-abstract were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [(0.8216867469879519, 0.1491818372449558, 0.6768210967742299), (0.8371681415929203, -0.1863928028104267, 0.3271564661763955), (0.8012578616352202, 0.1649150506281666, 0.6895854913749707), (0.781578947368421, 0.12828512277294654, 0.6679900561014893), (0.8241758241758241, 0.17764859323812446, 0.700082176733079)]

# %%
lst_models_2 = ['model_w/tsdae-declutr-base', 'model_w/tsdae-electra-base-discriminator',
                'model_w/tsdae-all-distilroberta-v1', 'model_w/tsdae-BiomedNLP-PubMedBERT-base-uncased-abstract']
scores_trained = []
for md in tqdm(lst_models_2):
    sentence_model = SentenceTransformer(md, device="cuda")
    topic_model = BERTopic(embedding_model=sentence_model)
    topics = topic_model.fit_transform(np.array(data_test))
    scores_trained.append(compute_metrics(topics, topic_model, np.array(data_test)))
print(scores_trained)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# [(0.8189189189189189, 0.16313223258919463, 0.695366367610592), (1.0, -0.03706645614338682, 0.449954260949123), (1.0, 0.06886228904641256, 0.4568813321059566), (0.8166666666666667, 0.14485702070906367, 0.6903788020275959)]

# %%
@torch.no_grad()
def objective(trial):
    torch.cuda.empty_cache()
    tnw = trial.suggest_int("top_n_words", 10, 30, log=True)
    ngr = trial.suggest_int("n_gram_range", 1, 3, log=True)
    mts = trial.suggest_int("min_topic_size", 5, 50, log=True)

    min_dist = trial.suggest_float("min_dist", 0.000001, 1, log=True)
    n_neigh = trial.suggest_int("n_neighbors", 2, 100, log=True)
    n_comp = trial.suggest_int("n_components", 10, 250, log=True)
    umap_model = umap.UMAP(
        n_neighbors=n_neigh,
        min_dist=min_dist,
        n_components=n_comp,
        random_state=42,
    )
    # cse = trial.suggest_float("cluster_selection_epsilon", 0.0001, 10, log=True)
    # mcs = trial.suggest_int("min_cluster_size", 2, 100, log=True)
    ms = trial.suggest_int("min_samples", 2, 40, log=True)
    hdbscan_model = hdbscan.HDBSCAN(min_samples=ms)
    topic_model = BERTopic(embedding_model=sentence_model, top_n_words=tnw, n_gram_range=(1, ngr), min_topic_size=mts,
                           umap_model=umap_model, hdbscan_model=hdbscan_model)
    try:
        topics = topic_model.fit_transform(np.array(data_val))
        return compute_metrics(topics, topic_model, np.array(data_val))[1]
    except:
        return -1

# %%
lst_models_3 = ['model_w/tsdae-declutr-base', 'model_w/tsdae-electra-base-discriminator',
                'model_w/tsdae-all-distilroberta-v1', 'model_w/tsdae-BiomedNLP-PubMedBERT-base-uncased-abstract',
                'all-mpnet-base-v2']
params_for_models = []
for md in lst_models_3:
    sentence_model = SentenceTransformer(md, device="cuda")
    study = optuna.create_study(direction="maximize")
    study.enqueue_trial(
        {
            'top_n_words': 10,
            'n_gram_range': 1,
            'min_topic_size': 10,
            'min_dist': 0.000001,
            'n_neighbors': 15,
            'n_components': 5,
            # 'cluster_selection_epsilon': 0.0,
            # 'min_cluster_size': 5,
            'min_samples': 5
        }
    )
    study.optimize(objective, n_trials=30, n_jobs=1)
    params_for_models.append(study.best_trial)
# Out:
# [I 2022-05-15 15:45:30,966] A new study created in memory with name: no-name-7c13ef6b-9088-4cfd-aedc-c9eec061244c
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: ExperimentalWarning: enqueue_trial is experimental (supported from v1.2.0). The interface can change in the future.
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py:857: ExperimentalWarning: create_trial is experimental (supported from v2.0.0). The interface can change in the future.
#   create_trial(state=TrialState.WAITING, system_attrs={"fixed_params": params})
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py:857: ExperimentalWarning: add_trial is experimental (supported from v2.0.0). The interface can change in the future.
#   create_trial(state=TrialState.WAITING, system_attrs={"fixed_params": params})
# [I 2022-05-15 15:47:21,668] Trial 0 finished with value: 0.033956954270832417 and parameters: {'top_n_words': 10, 'n_gram_range': 1, 'min_topic_size': 10, 'min_dist': 1e-06, 'n_neighbors': 15, 'n_components': 25, 'min_samples': 5}. Best is trial 0 with value: 0.033956954270832417.
# [I 2022-05-15 15:48:53,315] Trial 1 finished with value: 0.06132189501261065 and parameters: {'top_n_words': 21, 'n_gram_range': 1, 'min_topic_size': 11, 'min_dist': 7.535772053962225e-06, 'n_neighbors': 7, 'n_components': 22, 'min_samples': 9}. Best is trial 1 with value: 0.06132189501261065.
# [I 2022-05-15 15:51:30,519] Trial 2 finished with value: 0.0197056796061845 and parameters: {'top_n_words': 12, 'n_gram_range': 1, 'min_topic_size': 18, 'min_dist': 3.074661026982223e-05, 'n_neighbors': 38, 'n_components': 83, 'min_samples': 4}. Best is trial 1 with value: 0.06132189501261065.
# [I 2022-05-15 15:53:34,458] Trial 3 finished with value: 0.04136526717846958 and parameters: {'top_n_words': 22, 'n_gram_range': 1, 'min_topic_size': 21, 'min_dist': 4.3108449077738234e-05, 'n_neighbors': 4, 'n_components': 157, 'min_samples': 13}. Best is trial 1 with value: 0.06132189501261065.
# [I 2022-05-15 15:55:27,672] Trial 4 finished with value: 0.10418893336029342 and parameters: {'top_n_words': 16, 'n_gram_range': 1, 'min_topic_size': 10, 'min_dist': 0.0060904400578196405, 'n_neighbors': 24, 'n_components': 44, 'min_samples': 12}. Best is trial 4 with value: 0.10418893336029342.
# [I 2022-05-15 15:57:08,979] Trial 5 finished with value: -1.0 and parameters: {'top_n_words': 27, 'n_gram_range': 2, 'min_topic_size': 40, 'min_dist': 5.2394837358912305e-05, 'n_neighbors': 52, 'n_components': 21, 'min_samples': 3}. Best is trial 4 with value: 0.10418893336029342.
# [I 2022-05-15 16:00:00,495] Trial 6 finished with value: -1.0 and parameters: {'top_n_words': 15, 'n_gram_range': 2, 'min_topic_size': 13, 'min_dist': 2.9488310253365756e-05, 'n_neighbors': 13, 'n_components': 207, 'min_samples': 10}. Best is trial 4 with value: 0.10418893336029342.
# [I 2022-05-15 16:02:26,330] Trial 7 finished with value: 0.05843072083619171 and parameters: {'top_n_words': 29, 'n_gram_range': 1, 'min_topic_size': 5, 'min_dist': 6.622179213415169e-06, 'n_neighbors': 10, 'n_components': 145, 'min_samples': 10}. Best is trial 4 with value: 0.10418893336029342.
# [I 2022-05-15 16:04:52,352] Trial 8 finished with value: -1.0 and parameters: {'top_n_words': 16, 'n_gram_range': 2, 'min_topic_size': 33, 'min_dist': 1.445940738671536e-06, 'n_neighbors': 13, 'n_components': 162, 'min_samples': 16}. Best is trial 4 with value: 0.10418893336029342.
# [I 2022-05-15 16:05:50,850] Trial 9 finished with value: -1.0 and parameters: {'top_n_words': 14, 'n_gram_range': 2, 'min_topic_size': 49, 'min_dist': 0.00013672914800264935, 'n_neighbors': 3, 'n_components': 10, 'min_samples': 23}. Best is trial 4 with value: 0.10418893336029342.
# [I 2022-05-15 16:08:14,664] Trial 10 finished with value: -1.0 and parameters: {'top_n_words': 19, 'n_gram_range': 3, 'min_topic_size': 6, 'min_dist': 0.030303820799614658, 'n_neighbors': 75, 'n_components': 56, 'min_samples': 38}. Best is trial 4 with value: 0.10418893336029342.
# [I 2022-05-15 16:10:05,910] Trial 11 finished with value: 0.0740047931016549 and parameters: {'top_n_words': 21, 'n_gram_range': 1, 'min_topic_size': 9, 'min_dist': 0.00735274006693416, 'n_neighbors': 28, 'n_components': 31, 'min_samples': 6}. Best is trial 4 with value: 0.10418893336029342.
# [I 2022-05-15 16:12:03,098] Trial 12 finished with value: -0.0016607763118934016 and parameters: {'top_n_words': 24, 'n_gram_range': 1, 'min_topic_size': 8, 'min_dist': 0.015271554982298928, 'n_neighbors': 25, 'n_components': 39, 'min_samples': 2}. Best is trial 4 with value: 0.10418893336029342.
# [I 2022-05-15 16:13:46,497] Trial 13 finished with value: -1.0 and parameters: {'top_n_words': 18, 'n_gram_range': 3, 'min_topic_size': 7, 'min_dist': 0.7014614716513929, 'n_neighbors': 26, 'n_components': 42, 'min_samples': 6}. Best is trial 4 with value: 0.10418893336029342.
# [I 2022-05-15 16:16:28,057] Trial 14 finished with value: 0.14658467980924528 and parameters: {'top_n_words': 13, 'n_gram_range': 1, 'min_topic_size': 24, 'min_dist': 0.002488734602240512, 'n_neighbors': 99, 'n_components': 69, 'min_samples': 21}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:19:06,002] Trial 15 finished with value: -1.0 and parameters: {'top_n_words': 13, 'n_gram_range': 2, 'min_topic_size': 25, 'min_dist': 0.0011245469760055205, 'n_neighbors': 69, 'n_components': 83, 'min_samples': 30}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:21:53,178] Trial 16 finished with value: 0.07559424071500666 and parameters: {'top_n_words': 11, 'n_gram_range': 1, 'min_topic_size': 14, 'min_dist': 0.0012635369476574625, 'n_neighbors': 92, 'n_components': 77, 'min_samples': 19}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:22:57,905] Trial 17 finished with value: -1.0 and parameters: {'top_n_words': 17, 'n_gram_range': 3, 'min_topic_size': 27, 'min_dist': 0.23110714311292196, 'n_neighbors': 2, 'n_components': 14, 'min_samples': 25}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:25:11,998] Trial 18 finished with value: 0.07724592720405649 and parameters: {'top_n_words': 13, 'n_gram_range': 1, 'min_topic_size': 17, 'min_dist': 0.0038130465756872228, 'n_neighbors': 47, 'n_components': 61, 'min_samples': 14}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:28:14,319] Trial 19 finished with value: -1.0 and parameters: {'top_n_words': 10, 'n_gram_range': 2, 'min_topic_size': 12, 'min_dist': 0.06951492094100423, 'n_neighbors': 98, 'n_components': 105, 'min_samples': 39}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:30:02,357] Trial 20 finished with value: 0.13915168767546326 and parameters: {'top_n_words': 15, 'n_gram_range': 1, 'min_topic_size': 24, 'min_dist': 0.0003317120403477129, 'n_neighbors': 20, 'n_components': 49, 'min_samples': 19}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:31:47,905] Trial 21 finished with value: 0.055708560093392104 and parameters: {'top_n_words': 15, 'n_gram_range': 1, 'min_topic_size': 23, 'min_dist': 0.00023361870585480136, 'n_neighbors': 21, 'n_components': 52, 'min_samples': 18}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:33:17,173] Trial 22 finished with value: 0.0840122676218318 and parameters: {'top_n_words': 12, 'n_gram_range': 1, 'min_topic_size': 32, 'min_dist': 0.000440974947121029, 'n_neighbors': 8, 'n_components': 31, 'min_samples': 12}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:35:41,470] Trial 23 finished with value: 0.0886075604685982 and parameters: {'top_n_words': 14, 'n_gram_range': 1, 'min_topic_size': 19, 'min_dist': 0.0030368106529632165, 'n_neighbors': 19, 'n_components': 111, 'min_samples': 22}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:37:33,163] Trial 24 finished with value: 0.12935368496780367 and parameters: {'top_n_words': 16, 'n_gram_range': 1, 'min_topic_size': 15, 'min_dist': 0.0005887273482771603, 'n_neighbors': 35, 'n_components': 39, 'min_samples': 30}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:39:51,224] Trial 25 finished with value: 0.1308143876944554 and parameters: {'top_n_words': 12, 'n_gram_range': 1, 'min_topic_size': 15, 'min_dist': 0.000541669183386282, 'n_neighbors': 38, 'n_components': 66, 'min_samples': 26}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:42:22,732] Trial 26 finished with value: 0.08334804395491516 and parameters: {'top_n_words': 11, 'n_gram_range': 1, 'min_topic_size': 30, 'min_dist': 0.00018850738062945856, 'n_neighbors': 59, 'n_components': 64, 'min_samples': 27}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:45:15,594] Trial 27 finished with value: 0.08660073846558833 and parameters: {'top_n_words': 12, 'n_gram_range': 1, 'min_topic_size': 38, 'min_dist': 0.0016320345355914294, 'n_neighbors': 40, 'n_components': 106, 'min_samples': 19}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:46:48,638] Trial 28 finished with value: -1.0 and parameters: {'top_n_words': 11, 'n_gram_range': 2, 'min_topic_size': 21, 'min_dist': 0.00010686555513963705, 'n_neighbors': 6, 'n_components': 75, 'min_samples': 33}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:48:30,928] Trial 29 finished with value: 0.11653465348770994 and parameters: {'top_n_words': 10, 'n_gram_range': 1, 'min_topic_size': 16, 'min_dist': 0.0004142700667397451, 'n_neighbors': 19, 'n_components': 35, 'min_samples': 15}. Best is trial 14 with value: 0.14658467980924528.
# [I 2022-05-15 16:48:32,348] A new study created in memory with name: no-name-1a0ef601-073c-4bbc-a494-d4b915d7416c
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: ExperimentalWarning: enqueue_trial is experimental (supported from v1.2.0). The interface can change in the future.
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py:857: ExperimentalWarning: create_trial is experimental (supported from v2.0.0). The interface can change in the future.
#   create_trial(state=TrialState.WAITING, system_attrs={"fixed_params": params})
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py:857: ExperimentalWarning: add_trial is experimental (supported from v2.0.0). The interface can change in the future.
#   create_trial(state=TrialState.WAITING, system_attrs={"fixed_params": params})
# [I 2022-05-15 16:50:05,698] Trial 0 finished with value: -0.02315611218812784 and parameters: {'top_n_words': 10, 'n_gram_range': 1, 'min_topic_size': 10, 'min_dist': 1e-06, 'n_neighbors': 15, 'n_components': 21, 'min_samples': 5}. Best is trial 0 with value: -0.02315611218812784.
# [I 2022-05-15 16:52:57,162] Trial 1 finished with value: 0.09461561389893744 and parameters: {'top_n_words': 20, 'n_gram_range': 1, 'min_topic_size': 14, 'min_dist': 7.764204918080534e-05, 'n_neighbors': 77, 'n_components': 98, 'min_samples': 19}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 16:56:18,275] Trial 2 finished with value: -0.046840594665788174 and parameters: {'top_n_words': 15, 'n_gram_range': 1, 'min_topic_size': 23, 'min_dist': 1.7947151712864033e-06, 'n_neighbors': 36, 'n_components': 163, 'min_samples': 3}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 16:57:31,181] Trial 3 finished with value: -1.0 and parameters: {'top_n_words': 26, 'n_gram_range': 2, 'min_topic_size': 5, 'min_dist': 0.5092475670736434, 'n_neighbors': 8, 'n_components': 38, 'min_samples': 28}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 16:58:57,084] Trial 4 finished with value: -0.007187997547442819 and parameters: {'top_n_words': 30, 'n_gram_range': 1, 'min_topic_size': 8, 'min_dist': 5.365515855861318e-05, 'n_neighbors': 5, 'n_components': 19, 'min_samples': 6}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 17:00:53,344] Trial 5 finished with value: -0.02943026469468944 and parameters: {'top_n_words': 17, 'n_gram_range': 1, 'min_topic_size': 9, 'min_dist': 0.027532057501939978, 'n_neighbors': 34, 'n_components': 43, 'min_samples': 3}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 17:02:08,593] Trial 6 finished with value: -1.0 and parameters: {'top_n_words': 27, 'n_gram_range': 3, 'min_topic_size': 33, 'min_dist': 0.000948226284854348, 'n_neighbors': 15, 'n_components': 14, 'min_samples': 30}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 17:03:37,786] Trial 7 finished with value: 0.0678549486669011 and parameters: {'top_n_words': 15, 'n_gram_range': 1, 'min_topic_size': 12, 'min_dist': 1.604961828872409e-05, 'n_neighbors': 11, 'n_components': 39, 'min_samples': 22}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 17:05:10,805] Trial 8 finished with value: -0.02796996660401278 and parameters: {'top_n_words': 10, 'n_gram_range': 1, 'min_topic_size': 10, 'min_dist': 0.00040935631620123765, 'n_neighbors': 32, 'n_components': 10, 'min_samples': 3}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 17:06:49,420] Trial 9 finished with value: -0.03139257096946487 and parameters: {'top_n_words': 18, 'n_gram_range': 1, 'min_topic_size': 22, 'min_dist': 0.0013147338004269287, 'n_neighbors': 2, 'n_components': 151, 'min_samples': 11}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 17:09:25,755] Trial 10 finished with value: -1.0 and parameters: {'top_n_words': 22, 'n_gram_range': 2, 'min_topic_size': 49, 'min_dist': 0.016542278749268877, 'n_neighbors': 79, 'n_components': 87, 'min_samples': 13}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 17:12:01,561] Trial 11 finished with value: -1.0 and parameters: {'top_n_words': 13, 'n_gram_range': 2, 'min_topic_size': 16, 'min_dist': 2.350640169769463e-05, 'n_neighbors': 100, 'n_components': 77, 'min_samples': 18}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 17:13:16,197] Trial 12 finished with value: -1.0 and parameters: {'top_n_words': 21, 'n_gram_range': 2, 'min_topic_size': 15, 'min_dist': 2.536616239043184e-05, 'n_neighbors': 4, 'n_components': 72, 'min_samples': 19}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 17:14:39,611] Trial 13 finished with value: 0.06805544006560546 and parameters: {'top_n_words': 13, 'n_gram_range': 1, 'min_topic_size': 15, 'min_dist': 6.07628985382902e-05, 'n_neighbors': 9, 'n_components': 31, 'min_samples': 37}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 17:17:54,877] Trial 14 finished with value: -1.0 and parameters: {'top_n_words': 13, 'n_gram_range': 2, 'min_topic_size': 19, 'min_dist': 0.0003447599267015006, 'n_neighbors': 22, 'n_components': 238, 'min_samples': 39}. Best is trial 1 with value: 0.09461561389893744.
# [I 2022-05-15 17:19:45,679] Trial 15 finished with value: 0.10323190184613751 and parameters: {'top_n_words': 12, 'n_gram_range': 1, 'min_topic_size': 30, 'min_dist': 0.00016249619764201786, 'n_neighbors': 63, 'n_components': 28, 'min_samples': 40}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:22:01,966] Trial 16 finished with value: -1.0 and parameters: {'top_n_words': 20, 'n_gram_range': 3, 'min_topic_size': 31, 'min_dist': 0.005904871965593478, 'n_neighbors': 59, 'n_components': 63, 'min_samples': 12}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:24:48,877] Trial 17 finished with value: 0.08684171300920215 and parameters: {'top_n_words': 11, 'n_gram_range': 1, 'min_topic_size': 49, 'min_dist': 3.7996277176804225e-06, 'n_neighbors': 45, 'n_components': 114, 'min_samples': 8}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:26:39,111] Trial 18 finished with value: -1.0 and parameters: {'top_n_words': 24, 'n_gram_range': 3, 'min_topic_size': 34, 'min_dist': 0.0001470599808321107, 'n_neighbors': 62, 'n_components': 26, 'min_samples': 24}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:28:26,395] Trial 19 finished with value: -1.0 and parameters: {'top_n_words': 18, 'n_gram_range': 2, 'min_topic_size': 6, 'min_dist': 0.003607902413199862, 'n_neighbors': 27, 'n_components': 58, 'min_samples': 15}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:31:57,472] Trial 20 finished with value: -0.03135382563364572 and parameters: {'top_n_words': 15, 'n_gram_range': 1, 'min_topic_size': 26, 'min_dist': 6.0901585142076025e-06, 'n_neighbors': 100, 'n_components': 111, 'min_samples': 2}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:34:49,538] Trial 21 finished with value: 0.08995918651224959 and parameters: {'top_n_words': 11, 'n_gram_range': 1, 'min_topic_size': 49, 'min_dist': 5.308732169405544e-06, 'n_neighbors': 50, 'n_components': 112, 'min_samples': 8}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:39:05,652] Trial 22 finished with value: 0.07426306041411981 and parameters: {'top_n_words': 11, 'n_gram_range': 1, 'min_topic_size': 43, 'min_dist': 8.665492634291597e-06, 'n_neighbors': 50, 'n_components': 228, 'min_samples': 8}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:41:35,463] Trial 23 finished with value: 0.012442522992172772 and parameters: {'top_n_words': 12, 'n_gram_range': 1, 'min_topic_size': 40, 'min_dist': 0.00011741858824103294, 'n_neighbors': 21, 'n_components': 103, 'min_samples': 5}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:43:57,997] Trial 24 finished with value: 0.08966266575454117 and parameters: {'top_n_words': 11, 'n_gram_range': 1, 'min_topic_size': 26, 'min_dist': 0.00030741166588418064, 'n_neighbors': 65, 'n_components': 53, 'min_samples': 10}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:47:26,559] Trial 25 finished with value: 0.0604232283308429 and parameters: {'top_n_words': 16, 'n_gram_range': 1, 'min_topic_size': 36, 'min_dist': 3.040409717145421e-06, 'n_neighbors': 44, 'n_components': 167, 'min_samples': 16}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:50:54,491] Trial 26 finished with value: 0.09256899173927337 and parameters: {'top_n_words': 12, 'n_gram_range': 1, 'min_topic_size': 20, 'min_dist': 7.901997229715152e-05, 'n_neighbors': 77, 'n_components': 136, 'min_samples': 30}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:54:25,032] Trial 27 finished with value: 0.09330256277456786 and parameters: {'top_n_words': 14, 'n_gram_range': 1, 'min_topic_size': 19, 'min_dist': 7.729787791445689e-05, 'n_neighbors': 78, 'n_components': 139, 'min_samples': 29}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:57:08,002] Trial 28 finished with value: -1.0 and parameters: {'top_n_words': 14, 'n_gram_range': 2, 'min_topic_size': 13, 'min_dist': 0.0007366398523935291, 'n_neighbors': 79, 'n_components': 86, 'min_samples': 39}. Best is trial 15 with value: 0.10323190184613751.
# [I 2022-05-15 17:58:35,027] Trial 29 finished with value: 0.11922874311657132 and parameters: {'top_n_words': 19, 'n_gram_range': 1, 'min_topic_size': 18, 'min_dist': 0.002061925957379828, 'n_neighbors': 17, 'n_components': 22, 'min_samples': 22}. Best is trial 29 with value: 0.11922874311657132.
# [I 2022-05-15 17:58:36,415] A new study created in memory with name: no-name-db70c75c-4a03-4b00-8ab8-f5ed14bd26fa
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: ExperimentalWarning: enqueue_trial is experimental (supported from v1.2.0). The interface can change in the future.
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py:857: ExperimentalWarning: create_trial is experimental (supported from v2.0.0). The interface can change in the future.
#   create_trial(state=TrialState.WAITING, system_attrs={"fixed_params": params})
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py:857: ExperimentalWarning: add_trial is experimental (supported from v2.0.0). The interface can change in the future.
#   create_trial(state=TrialState.WAITING, system_attrs={"fixed_params": params})
# [I 2022-05-15 18:01:37,201] Trial 0 finished with value: 0.041834167960355266 and parameters: {'top_n_words': 10, 'n_gram_range': 1, 'min_topic_size': 10, 'min_dist': 1e-06, 'n_neighbors': 15, 'n_components': 208, 'min_samples': 5}. Best is trial 0 with value: 0.041834167960355266.
# [I 2022-05-15 18:05:38,998] Trial 1 finished with value: -1.0 and parameters: {'top_n_words': 19, 'n_gram_range': 2, 'min_topic_size': 9, 'min_dist': 0.010420020064590908, 'n_neighbors': 61, 'n_components': 214, 'min_samples': 29}. Best is trial 0 with value: 0.041834167960355266.
# [I 2022-05-15 18:07:56,591] Trial 2 finished with value: 0.08201542824493943 and parameters: {'top_n_words': 16, 'n_gram_range': 1, 'min_topic_size': 9, 'min_dist': 0.0021344478547316984, 'n_neighbors': 66, 'n_components': 68, 'min_samples': 7}. Best is trial 2 with value: 0.08201542824493943.
# [I 2022-05-15 18:08:49,235] Trial 3 finished with value: -1.0 and parameters: {'top_n_words': 11, 'n_gram_range': 2, 'min_topic_size': 7, 'min_dist': 0.035083758572813074, 'n_neighbors': 12, 'n_components': 12, 'min_samples': 3}. Best is trial 2 with value: 0.08201542824493943.
# [I 2022-05-15 18:11:39,587] Trial 4 finished with value: 0.01813553583942933 and parameters: {'top_n_words': 28, 'n_gram_range': 1, 'min_topic_size': 38, 'min_dist': 0.00010558247157487342, 'n_neighbors': 43, 'n_components': 114, 'min_samples': 3}. Best is trial 2 with value: 0.08201542824493943.
# [I 2022-05-15 18:12:49,975] Trial 5 finished with value: 0.03800220989114779 and parameters: {'top_n_words': 23, 'n_gram_range': 1, 'min_topic_size': 6, 'min_dist': 0.244164113355227, 'n_neighbors': 2, 'n_components': 87, 'min_samples': 19}. Best is trial 2 with value: 0.08201542824493943.
# [I 2022-05-15 18:14:37,020] Trial 6 finished with value: -1.0 and parameters: {'top_n_words': 26, 'n_gram_range': 3, 'min_topic_size': 5, 'min_dist': 0.050638378166307285, 'n_neighbors': 30, 'n_components': 60, 'min_samples': 20}. Best is trial 2 with value: 0.08201542824493943.
# [I 2022-05-15 18:16:13,614] Trial 7 finished with value: 0.09299844264964553 and parameters: {'top_n_words': 14, 'n_gram_range': 1, 'min_topic_size': 5, 'min_dist': 7.79579735835897e-06, 'n_neighbors': 45, 'n_components': 27, 'min_samples': 10}. Best is trial 7 with value: 0.09299844264964553.
# [I 2022-05-15 18:17:22,489] Trial 8 finished with value: 0.09861196766241621 and parameters: {'top_n_words': 12, 'n_gram_range': 1, 'min_topic_size': 43, 'min_dist': 0.003607520911458959, 'n_neighbors': 19, 'n_components': 15, 'min_samples': 39}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:19:47,425] Trial 9 finished with value: -1.0 and parameters: {'top_n_words': 15, 'n_gram_range': 2, 'min_topic_size': 19, 'min_dist': 0.02696719736225861, 'n_neighbors': 9, 'n_components': 226, 'min_samples': 2}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:20:35,192] Trial 10 finished with value: -1.0 and parameters: {'top_n_words': 12, 'n_gram_range': 3, 'min_topic_size': 50, 'min_dist': 0.00024951328354597455, 'n_neighbors': 4, 'n_components': 10, 'min_samples': 35}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:22:31,111] Trial 11 finished with value: 0.09210388737882153 and parameters: {'top_n_words': 13, 'n_gram_range': 1, 'min_topic_size': 22, 'min_dist': 8.84933212706566e-06, 'n_neighbors': 98, 'n_components': 27, 'min_samples': 12}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:23:40,272] Trial 12 finished with value: -1.0 and parameters: {'top_n_words': 13, 'n_gram_range': 2, 'min_topic_size': 30, 'min_dist': 2.6134261829726365e-05, 'n_neighbors': 23, 'n_components': 26, 'min_samples': 12}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:24:46,987] Trial 13 finished with value: 0.07107831292086197 and parameters: {'top_n_words': 19, 'n_gram_range': 1, 'min_topic_size': 14, 'min_dist': 0.0005440159718246381, 'n_neighbors': 7, 'n_components': 21, 'min_samples': 12}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:26:05,120] Trial 14 finished with value: 0.06795318030532917 and parameters: {'top_n_words': 14, 'n_gram_range': 1, 'min_topic_size': 14, 'min_dist': 0.002411736631603883, 'n_neighbors': 24, 'n_components': 17, 'min_samples': 6}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:27:17,438] Trial 15 finished with value: -1.0 and parameters: {'top_n_words': 10, 'n_gram_range': 2, 'min_topic_size': 27, 'min_dist': 1.1077928251380493e-06, 'n_neighbors': 18, 'n_components': 39, 'min_samples': 21}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:28:49,775] Trial 16 finished with value: -0.0010059451274540554 and parameters: {'top_n_words': 18, 'n_gram_range': 1, 'min_topic_size': 48, 'min_dist': 0.9774451109172408, 'n_neighbors': 36, 'n_components': 38, 'min_samples': 37}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:29:43,204] Trial 17 finished with value: -1.0 and parameters: {'top_n_words': 12, 'n_gram_range': 3, 'min_topic_size': 12, 'min_dist': 2.9022632558755512e-05, 'n_neighbors': 6, 'n_components': 15, 'min_samples': 10}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:31:34,557] Trial 18 finished with value: 0.028339509352214697 and parameters: {'top_n_words': 22, 'n_gram_range': 1, 'min_topic_size': 19, 'min_dist': 0.004589527848659351, 'n_neighbors': 51, 'n_components': 38, 'min_samples': 4}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:32:18,984] Trial 19 finished with value: -1.0 and parameters: {'top_n_words': 15, 'n_gram_range': 2, 'min_topic_size': 5, 'min_dist': 4.874461159933209e-06, 'n_neighbors': 3, 'n_components': 25, 'min_samples': 26}. Best is trial 8 with value: 0.09861196766241621.
# [I 2022-05-15 18:33:55,036] Trial 20 finished with value: 0.11680023758479463 and parameters: {'top_n_words': 17, 'n_gram_range': 1, 'min_topic_size': 35, 'min_dist': 0.00010558801016870817, 'n_neighbors': 82, 'n_components': 15, 'min_samples': 16}. Best is trial 20 with value: 0.11680023758479463.
# [I 2022-05-15 18:35:36,605] Trial 21 finished with value: 0.0963497355796678 and parameters: {'top_n_words': 17, 'n_gram_range': 1, 'min_topic_size': 34, 'min_dist': 9.487848212495245e-05, 'n_neighbors': 96, 'n_components': 15, 'min_samples': 9}. Best is trial 20 with value: 0.11680023758479463.
# [I 2022-05-15 18:37:16,100] Trial 22 finished with value: 0.1098543159967901 and parameters: {'top_n_words': 22, 'n_gram_range': 1, 'min_topic_size': 37, 'min_dist': 0.00010859119116023738, 'n_neighbors': 98, 'n_components': 14, 'min_samples': 18}. Best is trial 20 with value: 0.11680023758479463.
# [I 2022-05-15 18:38:44,295] Trial 23 finished with value: 0.12536210967682837 and parameters: {'top_n_words': 21, 'n_gram_range': 1, 'min_topic_size': 40, 'min_dist': 0.0005313624346553605, 'n_neighbors': 78, 'n_components': 10, 'min_samples': 16}. Best is trial 23 with value: 0.12536210967682837.
# [I 2022-05-15 18:40:12,217] Trial 24 finished with value: 0.1111432019961079 and parameters: {'top_n_words': 22, 'n_gram_range': 1, 'min_topic_size': 26, 'min_dist': 0.0004864677039848333, 'n_neighbors': 77, 'n_components': 10, 'min_samples': 16}. Best is trial 23 with value: 0.12536210967682837.
# [I 2022-05-15 18:41:38,332] Trial 25 finished with value: 0.08921851353373529 and parameters: {'top_n_words': 24, 'n_gram_range': 1, 'min_topic_size': 25, 'min_dist': 0.0005625551215390952, 'n_neighbors': 71, 'n_components': 10, 'min_samples': 15}. Best is trial 23 with value: 0.12536210967682837.
# [I 2022-05-15 18:43:04,351] Trial 26 finished with value: 0.07908062722342189 and parameters: {'top_n_words': 20, 'n_gram_range': 1, 'min_topic_size': 30, 'min_dist': 0.0010338291863576216, 'n_neighbors': 68, 'n_components': 11, 'min_samples': 15}. Best is trial 23 with value: 0.12536210967682837.
# [I 2022-05-15 18:44:25,021] Trial 27 finished with value: 0.11004396143277423 and parameters: {'top_n_words': 30, 'n_gram_range': 1, 'min_topic_size': 23, 'min_dist': 3.6908776302655005e-05, 'n_neighbors': 34, 'n_components': 19, 'min_samples': 27}. Best is trial 23 with value: 0.12536210967682837.
# [I 2022-05-15 18:45:36,775] Trial 28 finished with value: -1.0 and parameters: {'top_n_words': 21, 'n_gram_range': 2, 'min_topic_size': 18, 'min_dist': 0.00037519277952130595, 'n_neighbors': 53, 'n_components': 13, 'min_samples': 15}. Best is trial 23 with value: 0.12536210967682837.
# [I 2022-05-15 18:47:07,495] Trial 29 finished with value: 0.08101502945392741 and parameters: {'top_n_words': 17, 'n_gram_range': 1, 'min_topic_size': 32, 'min_dist': 0.00013279005040032113, 'n_neighbors': 81, 'n_components': 10, 'min_samples': 8}. Best is trial 23 with value: 0.12536210967682837.
# [I 2022-05-15 18:47:08,870] A new study created in memory with name: no-name-eabcd964-e511-4d25-9768-86f61b92c560
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: ExperimentalWarning: enqueue_trial is experimental (supported from v1.2.0). The interface can change in the future.
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py:857: ExperimentalWarning: create_trial is experimental (supported from v2.0.0). The interface can change in the future.
#   create_trial(state=TrialState.WAITING, system_attrs={"fixed_params": params})
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py:857: ExperimentalWarning: add_trial is experimental (supported from v2.0.0). The interface can change in the future.
#   create_trial(state=TrialState.WAITING, system_attrs={"fixed_params": params})
# [I 2022-05-15 18:50:14,129] Trial 0 finished with value: 0.07249625788222124 and parameters: {'top_n_words': 10, 'n_gram_range': 1, 'min_topic_size': 10, 'min_dist': 1e-06, 'n_neighbors': 15, 'n_components': 187, 'min_samples': 5}. Best is trial 0 with value: 0.07249625788222124.
# [I 2022-05-15 18:51:38,583] Trial 1 finished with value: 0.05884412516469325 and parameters: {'top_n_words': 12, 'n_gram_range': 1, 'min_topic_size': 8, 'min_dist': 0.11453398995719395, 'n_neighbors': 6, 'n_components': 22, 'min_samples': 5}. Best is trial 0 with value: 0.07249625788222124.
# [I 2022-05-15 18:53:06,010] Trial 2 finished with value: 0.06097720211949056 and parameters: {'top_n_words': 29, 'n_gram_range': 1, 'min_topic_size': 18, 'min_dist': 0.16419641624968404, 'n_neighbors': 35, 'n_components': 15, 'min_samples': 25}. Best is trial 0 with value: 0.07249625788222124.
# [I 2022-05-15 18:55:41,471] Trial 3 finished with value: -1.0 and parameters: {'top_n_words': 18, 'n_gram_range': 2, 'min_topic_size': 10, 'min_dist': 1.3140116916976614e-06, 'n_neighbors': 26, 'n_components': 138, 'min_samples': 24}. Best is trial 0 with value: 0.07249625788222124.
# [I 2022-05-15 18:56:51,938] Trial 4 finished with value: 0.08947793883805337 and parameters: {'top_n_words': 18, 'n_gram_range': 1, 'min_topic_size': 5, 'min_dist': 0.0002498568509942621, 'n_neighbors': 7, 'n_components': 10, 'min_samples': 16}. Best is trial 4 with value: 0.08947793883805337.
# [I 2022-05-15 18:59:28,560] Trial 5 finished with value: 0.07573382513232793 and parameters: {'top_n_words': 11, 'n_gram_range': 1, 'min_topic_size': 43, 'min_dist': 0.11901476862231013, 'n_neighbors': 45, 'n_components': 99, 'min_samples': 25}. Best is trial 4 with value: 0.08947793883805337.
# [I 2022-05-15 19:00:43,834] Trial 6 finished with value: -1.0 and parameters: {'top_n_words': 20, 'n_gram_range': 3, 'min_topic_size': 16, 'min_dist': 2.4037439924334266e-05, 'n_neighbors': 4, 'n_components': 45, 'min_samples': 24}. Best is trial 4 with value: 0.08947793883805337.
# [I 2022-05-15 19:03:05,884] Trial 7 finished with value: -0.0012705379079491683 and parameters: {'top_n_words': 21, 'n_gram_range': 1, 'min_topic_size': 38, 'min_dist': 0.007689483703309829, 'n_neighbors': 7, 'n_components': 142, 'min_samples': 2}. Best is trial 4 with value: 0.08947793883805337.
# [I 2022-05-15 19:05:46,305] Trial 8 finished with value: -1.0 and parameters: {'top_n_words': 10, 'n_gram_range': 2, 'min_topic_size': 5, 'min_dist': 0.8701038186546891, 'n_neighbors': 8, 'n_components': 235, 'min_samples': 16}. Best is trial 4 with value: 0.08947793883805337.
# [I 2022-05-15 19:07:10,856] Trial 9 finished with value: -1.0 and parameters: {'top_n_words': 16, 'n_gram_range': 3, 'min_topic_size': 37, 'min_dist': 0.20142077666567149, 'n_neighbors': 6, 'n_components': 55, 'min_samples': 7}. Best is trial 4 with value: 0.08947793883805337.
# [I 2022-05-15 19:08:07,499] Trial 10 finished with value: -1.0 and parameters: {'top_n_words': 14, 'n_gram_range': 2, 'min_topic_size': 6, 'min_dist': 0.00033429756186015633, 'n_neighbors': 2, 'n_components': 12, 'min_samples': 12}. Best is trial 4 with value: 0.08947793883805337.
# [I 2022-05-15 19:10:38,883] Trial 11 finished with value: 0.09691339995870528 and parameters: {'top_n_words': 13, 'n_gram_range': 1, 'min_topic_size': 26, 'min_dist': 0.0025437063158036226, 'n_neighbors': 76, 'n_components': 69, 'min_samples': 40}. Best is trial 11 with value: 0.09691339995870528.
# [I 2022-05-15 19:12:33,744] Trial 12 finished with value: -1.0 and parameters: {'top_n_words': 14, 'n_gram_range': 2, 'min_topic_size': 26, 'min_dist': 0.0010748800252846154, 'n_neighbors': 91, 'n_components': 34, 'min_samples': 40}. Best is trial 11 with value: 0.09691339995870528.
# [I 2022-05-15 19:15:13,923] Trial 13 finished with value: 0.1122773296190464 and parameters: {'top_n_words': 24, 'n_gram_range': 1, 'min_topic_size': 27, 'min_dist': 0.000283309181305762, 'n_neighbors': 100, 'n_components': 69, 'min_samples': 40}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:17:57,901] Trial 14 finished with value: 0.04674832741391931 and parameters: {'top_n_words': 27, 'n_gram_range': 1, 'min_topic_size': 23, 'min_dist': 0.006494059512685635, 'n_neighbors': 87, 'n_components': 77, 'min_samples': 36}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:20:16,319] Trial 15 finished with value: -1.0 and parameters: {'top_n_words': 24, 'n_gram_range': 2, 'min_topic_size': 28, 'min_dist': 2.750209845845007e-05, 'n_neighbors': 57, 'n_components': 73, 'min_samples': 10}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:22:06,820] Trial 16 finished with value: 0.0033849553006562003 and parameters: {'top_n_words': 14, 'n_gram_range': 1, 'min_topic_size': 21, 'min_dist': 0.005353716820184417, 'n_neighbors': 20, 'n_components': 31, 'min_samples': 2}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:24:44,817] Trial 17 finished with value: -1.0 and parameters: {'top_n_words': 22, 'n_gram_range': 3, 'min_topic_size': 50, 'min_dist': 2.4417492169773866e-05, 'n_neighbors': 61, 'n_components': 96, 'min_samples': 39}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:26:58,974] Trial 18 finished with value: 0.02424792620549056 and parameters: {'top_n_words': 16, 'n_gram_range': 1, 'min_topic_size': 30, 'min_dist': 0.00016103848979721533, 'n_neighbors': 35, 'n_components': 57, 'min_samples': 3}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:29:00,515] Trial 19 finished with value: -1.0 and parameters: {'top_n_words': 25, 'n_gram_range': 2, 'min_topic_size': 13, 'min_dist': 0.001620692876578636, 'n_neighbors': 95, 'n_components': 38, 'min_samples': 16}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:30:46,615] Trial 20 finished with value: 0.07131186353176767 and parameters: {'top_n_words': 12, 'n_gram_range': 1, 'min_topic_size': 14, 'min_dist': 0.03822089659564959, 'n_neighbors': 57, 'n_components': 25, 'min_samples': 32}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:32:32,074] Trial 21 finished with value: 0.058497944781207095 and parameters: {'top_n_words': 18, 'n_gram_range': 1, 'min_topic_size': 32, 'min_dist': 0.00013964970904144873, 'n_neighbors': 12, 'n_components': 70, 'min_samples': 18}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:33:49,604] Trial 22 finished with value: 0.03350889311837953 and parameters: {'top_n_words': 19, 'n_gram_range': 1, 'min_topic_size': 20, 'min_dist': 0.00044772959911146347, 'n_neighbors': 3, 'n_components': 16, 'min_samples': 12}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:35:59,798] Trial 23 finished with value: 0.10378576081563448 and parameters: {'top_n_words': 23, 'n_gram_range': 1, 'min_topic_size': 7, 'min_dist': 6.68158904364182e-05, 'n_neighbors': 12, 'n_components': 115, 'min_samples': 19}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:38:08,335] Trial 24 finished with value: 0.07838565709323318 and parameters: {'top_n_words': 24, 'n_gram_range': 1, 'min_topic_size': 7, 'min_dist': 5.210967996945116e-06, 'n_neighbors': 12, 'n_components': 115, 'min_samples': 29}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:41:02,448] Trial 25 finished with value: 0.10224504725409407 and parameters: {'top_n_words': 30, 'n_gram_range': 1, 'min_topic_size': 11, 'min_dist': 6.98436724769667e-05, 'n_neighbors': 22, 'n_components': 157, 'min_samples': 20}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:43:50,381] Trial 26 finished with value: 0.07615793008143479 and parameters: {'top_n_words': 30, 'n_gram_range': 1, 'min_topic_size': 10, 'min_dist': 6.914951612757002e-05, 'n_neighbors': 18, 'n_components': 169, 'min_samples': 20}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:46:51,746] Trial 27 finished with value: 0.059886334861068126 and parameters: {'top_n_words': 27, 'n_gram_range': 1, 'min_topic_size': 8, 'min_dist': 3.9712942544872575e-06, 'n_neighbors': 10, 'n_components': 234, 'min_samples': 8}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:49:10,954] Trial 28 finished with value: -1.0 and parameters: {'top_n_words': 27, 'n_gram_range': 2, 'min_topic_size': 12, 'min_dist': 8.612196104669746e-05, 'n_neighbors': 26, 'n_components': 113, 'min_samples': 13}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:51:50,770] Trial 29 finished with value: 0.0715862990066559 and parameters: {'top_n_words': 23, 'n_gram_range': 1, 'min_topic_size': 11, 'min_dist': 9.008702391435746e-06, 'n_neighbors': 16, 'n_components': 164, 'min_samples': 6}. Best is trial 13 with value: 0.1122773296190464.
# [I 2022-05-15 19:51:58,597] A new study created in memory with name: no-name-6b459e6b-6753-4a39-ae72-01d6b55f784e
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: ExperimentalWarning: enqueue_trial is experimental (supported from v1.2.0). The interface can change in the future.
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py:857: ExperimentalWarning: create_trial is experimental (supported from v2.0.0). The interface can change in the future.
#   create_trial(state=TrialState.WAITING, system_attrs={"fixed_params": params})
# /opt/conda/lib/python3.7/site-packages/optuna/study/study.py:857: ExperimentalWarning: add_trial is experimental (supported from v2.0.0). The interface can change in the future.
#   create_trial(state=TrialState.WAITING, system_attrs={"fixed_params": params})
# [I 2022-05-15 19:53:27,921] Trial 0 finished with value: 0.08904191879988668 and parameters: {'top_n_words': 10, 'n_gram_range': 1, 'min_topic_size': 10, 'min_dist': 1e-06, 'n_neighbors': 15, 'n_components': 10, 'min_samples': 5}. Best is trial 0 with value: 0.08904191879988668.
# [I 2022-05-15 19:55:04,918] Trial 1 finished with value: 0.11842580804919375 and parameters: {'top_n_words': 25, 'n_gram_range': 1, 'min_topic_size': 7, 'min_dist': 2.7862500380234867e-06, 'n_neighbors': 17, 'n_components': 33, 'min_samples': 8}. Best is trial 1 with value: 0.11842580804919375.
# [I 2022-05-15 19:56:37,157] Trial 2 finished with value: 0.06627173620934419 and parameters: {'top_n_words': 21, 'n_gram_range': 1, 'min_topic_size': 33, 'min_dist': 3.067292073215002e-05, 'n_neighbors': 7, 'n_components': 11, 'min_samples': 3}. Best is trial 1 with value: 0.11842580804919375.
# [I 2022-05-15 19:57:57,781] Trial 3 finished with value: 0.1278948940743456 and parameters: {'top_n_words': 16, 'n_gram_range': 1, 'min_topic_size': 22, 'min_dist': 4.53310622866615e-06, 'n_neighbors': 10, 'n_components': 23, 'min_samples': 23}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 19:59:31,916] Trial 4 finished with value: -1.0 and parameters: {'top_n_words': 10, 'n_gram_range': 3, 'min_topic_size': 6, 'min_dist': 0.04460200324247628, 'n_neighbors': 3, 'n_components': 142, 'min_samples': 17}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:00:57,667] Trial 5 finished with value: 0.018980895764425746 and parameters: {'top_n_words': 19, 'n_gram_range': 1, 'min_topic_size': 24, 'min_dist': 0.029248874549123966, 'n_neighbors': 42, 'n_components': 15, 'min_samples': 15}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:02:37,948] Trial 6 finished with value: 0.0021822759505035353 and parameters: {'top_n_words': 14, 'n_gram_range': 1, 'min_topic_size': 33, 'min_dist': 0.012197931241205875, 'n_neighbors': 2, 'n_components': 16, 'min_samples': 4}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:04:33,611] Trial 7 finished with value: 0.018980895764425746 and parameters: {'top_n_words': 10, 'n_gram_range': 1, 'min_topic_size': 10, 'min_dist': 0.0001136264492616939, 'n_neighbors': 96, 'n_components': 33, 'min_samples': 9}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:06:12,232] Trial 8 finished with value: -1.0 and parameters: {'top_n_words': 11, 'n_gram_range': 2, 'min_topic_size': 27, 'min_dist': 0.035097641920464905, 'n_neighbors': 82, 'n_components': 20, 'min_samples': 5}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:09:24,494] Trial 9 finished with value: -0.024723159097279263 and parameters: {'top_n_words': 16, 'n_gram_range': 2, 'min_topic_size': 8, 'min_dist': 0.01086162582326471, 'n_neighbors': 17, 'n_components': 242, 'min_samples': 29}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:10:48,218] Trial 10 finished with value: -1.0 and parameters: {'top_n_words': 28, 'n_gram_range': 2, 'min_topic_size': 16, 'min_dist': 0.5436218411736289, 'n_neighbors': 5, 'n_components': 85, 'min_samples': 39}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:12:42,354] Trial 11 finished with value: 0.054095287874288765 and parameters: {'top_n_words': 26, 'n_gram_range': 1, 'min_topic_size': 18, 'min_dist': 1.5940348029486065e-06, 'n_neighbors': 24, 'n_components': 38, 'min_samples': 2}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:14:06,741] Trial 12 finished with value: -1.0 and parameters: {'top_n_words': 23, 'n_gram_range': 2, 'min_topic_size': 5, 'min_dist': 1.9986627039003794e-05, 'n_neighbors': 8, 'n_components': 61, 'min_samples': 11}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:15:46,726] Trial 13 finished with value: -0.024723159097279263 and parameters: {'top_n_words': 15, 'n_gram_range': 3, 'min_topic_size': 50, 'min_dist': 0.0006597965345755643, 'n_neighbors': 27, 'n_components': 26, 'min_samples': 22}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:17:34,333] Trial 14 finished with value: 0.09989631221995204 and parameters: {'top_n_words': 18, 'n_gram_range': 1, 'min_topic_size': 13, 'min_dist': 6.639456654290741e-06, 'n_neighbors': 12, 'n_components': 56, 'min_samples': 7}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:19:04,883] Trial 15 finished with value: -1.0 and parameters: {'top_n_words': 12, 'n_gram_range': 2, 'min_topic_size': 7, 'min_dist': 0.0001787477684722679, 'n_neighbors': 44, 'n_components': 25, 'min_samples': 13}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:20:23,742] Trial 16 finished with value: 0.11951169717980664 and parameters: {'top_n_words': 13, 'n_gram_range': 1, 'min_topic_size': 12, 'min_dist': 6.6804743541027194e-06, 'n_neighbors': 4, 'n_components': 43, 'min_samples': 23}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:21:48,588] Trial 17 finished with value: -1.0 and parameters: {'top_n_words': 13, 'n_gram_range': 3, 'min_topic_size': 20, 'min_dist': 1.532271882874917e-05, 'n_neighbors': 4, 'n_components': 83, 'min_samples': 24}. Best is trial 3 with value: 0.1278948940743456.
# [I 2022-05-15 20:23:06,496] Trial 18 finished with value: 0.13837849172694328 and parameters: {'top_n_words': 17, 'n_gram_range': 1, 'min_topic_size': 13, 'min_dist': 8.861940683218052e-05, 'n_neighbors': 2, 'n_components': 45, 'min_samples': 32}. Best is trial 18 with value: 0.13837849172694328.
# [I 2022-05-15 20:24:19,657] Trial 19 finished with value: -1.0 and parameters: {'top_n_words': 20, 'n_gram_range': 2, 'min_topic_size': 49, 'min_dist': 0.0017015494838312384, 'n_neighbors': 2, 'n_components': 91, 'min_samples': 39}. Best is trial 18 with value: 0.13837849172694328.
# [I 2022-05-15 20:25:36,103] Trial 20 finished with value: 0.029647595741593268 and parameters: {'top_n_words': 17, 'n_gram_range': 1, 'min_topic_size': 22, 'min_dist': 9.655527248377984e-05, 'n_neighbors': 9, 'n_components': 23, 'min_samples': 31}. Best is trial 18 with value: 0.13837849172694328.
# [I 2022-05-15 20:26:53,357] Trial 21 finished with value: 0.10608570596565953 and parameters: {'top_n_words': 14, 'n_gram_range': 1, 'min_topic_size': 13, 'min_dist': 5.628941197207314e-06, 'n_neighbors': 3, 'n_components': 44, 'min_samples': 20}. Best is trial 18 with value: 0.13837849172694328.
# [I 2022-05-15 20:28:11,170] Trial 22 finished with value: 0.02589176311201484 and parameters: {'top_n_words': 16, 'n_gram_range': 1, 'min_topic_size': 12, 'min_dist': 2.9203685272506646e-05, 'n_neighbors': 5, 'n_components': 53, 'min_samples': 28}. Best is trial 18 with value: 0.13837849172694328.
# [I 2022-05-15 20:29:35,954] Trial 23 finished with value: 0.10778851075788999 and parameters: {'top_n_words': 13, 'n_gram_range': 1, 'min_topic_size': 16, 'min_dist': 0.0006373849840123756, 'n_neighbors': 3, 'n_components': 68, 'min_samples': 18}. Best is trial 18 with value: 0.13837849172694328.
# [I 2022-05-15 20:30:58,458] Trial 24 finished with value: 0.08371699699017894 and parameters: {'top_n_words': 12, 'n_gram_range': 1, 'min_topic_size': 10, 'min_dist': 4.9546799282503095e-06, 'n_neighbors': 2, 'n_components': 42, 'min_samples': 13}. Best is trial 18 with value: 0.13837849172694328.
# [I 2022-05-15 20:32:38,805] Trial 25 finished with value: 0.05011453611313064 and parameters: {'top_n_words': 17, 'n_gram_range': 1, 'min_topic_size': 29, 'min_dist': 7.509609649800224e-05, 'n_neighbors': 5, 'n_components': 122, 'min_samples': 32}. Best is trial 18 with value: 0.13837849172694328.
# [I 2022-05-15 20:33:52,337] Trial 26 finished with value: 0.1081988206889754 and parameters: {'top_n_words': 15, 'n_gram_range': 1, 'min_topic_size': 14, 'min_dist': 0.0002767378991846932, 'n_neighbors': 3, 'n_components': 31, 'min_samples': 26}. Best is trial 18 with value: 0.13837849172694328.
# [I 2022-05-15 20:35:09,655] Trial 27 finished with value: 0.11399069457352744 and parameters: {'top_n_words': 19, 'n_gram_range': 1, 'min_topic_size': 19, 'min_dist': 1.5206949380348567e-05, 'n_neighbors': 11, 'n_components': 17, 'min_samples': 40}. Best is trial 18 with value: 0.13837849172694328.
# [I 2022-05-15 20:36:10,303] Trial 28 finished with value: -1.0 and parameters: {'top_n_words': 22, 'n_gram_range': 2, 'min_topic_size': 9, 'min_dist': 0.0019886349490293833, 'n_neighbors': 6, 'n_components': 13, 'min_samples': 21}. Best is trial 18 with value: 0.13837849172694328.
# [I 2022-05-15 20:37:29,437] Trial 29 finished with value: 0.08757009431335151 and parameters: {'top_n_words': 11, 'n_gram_range': 1, 'min_topic_size': 11, 'min_dist': 1.2095491080382754e-06, 'n_neighbors': 4, 'n_components': 21, 'min_samples': 10}. Best is trial 18 with value: 0.13837849172694328.

# %%
print(params_for_models)
# Out:
# [FrozenTrial(number=14, values=[0.14658467980924528], datetime_start=datetime.datetime(2022, 5, 15, 16, 13, 46, 500291), datetime_complete=datetime.datetime(2022, 5, 15, 16, 16, 28, 56658), params={'top_n_words': 13, 'n_gram_range': 1, 'min_topic_size': 24, 'min_dist': 0.002488734602240512, 'n_neighbors': 99, 'n_components': 69, 'min_samples': 21}, distributions={'top_n_words': IntLogUniformDistribution(high=30, low=10, step=1), 'n_gram_range': IntLogUniformDistribution(high=3, low=1, step=1), 'min_topic_size': IntLogUniformDistribution(high=50, low=5, step=1), 'min_dist': LogUniformDistribution(high=1.0, low=1e-06), 'n_neighbors': IntLogUniformDistribution(high=100, low=2, step=1), 'n_components': IntLogUniformDistribution(high=250, low=10, step=1), 'min_samples': IntLogUniformDistribution(high=40, low=2, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=14, state=TrialState.COMPLETE, value=None), FrozenTrial(number=29, values=[0.11922874311657132], datetime_start=datetime.datetime(2022, 5, 15, 17, 57, 8, 6508), datetime_complete=datetime.datetime(2022, 5, 15, 17, 58, 35, 27205), params={'top_n_words': 19, 'n_gram_range': 1, 'min_topic_size': 18, 'min_dist': 0.002061925957379828, 'n_neighbors': 17, 'n_components': 22, 'min_samples': 22}, distributions={'top_n_words': IntLogUniformDistribution(high=30, low=10, step=1), 'n_gram_range': IntLogUniformDistribution(high=3, low=1, step=1), 'min_topic_size': IntLogUniformDistribution(high=50, low=5, step=1), 'min_dist': LogUniformDistribution(high=1.0, low=1e-06), 'n_neighbors': IntLogUniformDistribution(high=100, low=2, step=1), 'n_components': IntLogUniformDistribution(high=250, low=10, step=1), 'min_samples': IntLogUniformDistribution(high=40, low=2, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=29, state=TrialState.COMPLETE, value=None), FrozenTrial(number=23, values=[0.12536210967682837], datetime_start=datetime.datetime(2022, 5, 15, 18, 37, 16, 103209), datetime_complete=datetime.datetime(2022, 5, 15, 18, 38, 44, 294512), params={'top_n_words': 21, 'n_gram_range': 1, 'min_topic_size': 40, 'min_dist': 0.0005313624346553605, 'n_neighbors': 78, 'n_components': 10, 'min_samples': 16}, distributions={'top_n_words': IntLogUniformDistribution(high=30, low=10, step=1), 'n_gram_range': IntLogUniformDistribution(high=3, low=1, step=1), 'min_topic_size': IntLogUniformDistribution(high=50, low=5, step=1), 'min_dist': LogUniformDistribution(high=1.0, low=1e-06), 'n_neighbors': IntLogUniformDistribution(high=100, low=2, step=1), 'n_components': IntLogUniformDistribution(high=250, low=10, step=1), 'min_samples': IntLogUniformDistribution(high=40, low=2, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=23, state=TrialState.COMPLETE, value=None), FrozenTrial(number=13, values=[0.1122773296190464], datetime_start=datetime.datetime(2022, 5, 15, 19, 12, 33, 747914), datetime_complete=datetime.datetime(2022, 5, 15, 19, 15, 13, 922553), params={'top_n_words': 24, 'n_gram_range': 1, 'min_topic_size': 27, 'min_dist': 0.000283309181305762, 'n_neighbors': 100, 'n_components': 69, 'min_samples': 40}, distributions={'top_n_words': IntLogUniformDistribution(high=30, low=10, step=1), 'n_gram_range': IntLogUniformDistribution(high=3, low=1, step=1), 'min_topic_size': IntLogUniformDistribution(high=50, low=5, step=1), 'min_dist': LogUniformDistribution(high=1.0, low=1e-06), 'n_neighbors': IntLogUniformDistribution(high=100, low=2, step=1), 'n_components': IntLogUniformDistribution(high=250, low=10, step=1), 'min_samples': IntLogUniformDistribution(high=40, low=2, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=13, state=TrialState.COMPLETE, value=None), FrozenTrial(number=18, values=[0.13837849172694328], datetime_start=datetime.datetime(2022, 5, 15, 20, 21, 48, 590847), datetime_complete=datetime.datetime(2022, 5, 15, 20, 23, 6, 495906), params={'top_n_words': 17, 'n_gram_range': 1, 'min_topic_size': 13 ...

# %%
def extract_pars(dct):
    tmp = dict()
    tmp['min_dist'] = dct['min_dist']
    tmp['n_neighbors'] = dct['n_neighbors']
    tmp['n_components'] = dct['n_components']
    tmp_1 = dict()
    # tmp_1['cluster_selection_epsilon'] = dct['cluster_selection_epsilon']
    # tmp_1['min_cluster_size'] = dct['min_cluster_size']
    tmp_1['min_samples'] = dct['min_samples']
    tmp_2 = dict()
    tmp_2['top_n_words'] = dct['top_n_words']
    tmp_2['n_gram_range'] = (1, dct['n_gram_range'])
    tmp_2['min_topic_size'] = dct['min_topic_size']
    return tmp, tmp_1, tmp_2

# %%
scores_paramed= []
lst_models_3 = ['model_w/tsdae-declutr-base', 'model_w/tsdae-electra-base-discriminator',
                'model_w/tsdae-all-distilroberta-v1', 'model_w/tsdae-BiomedNLP-PubMedBERT-base-uncased-abstract',
                'all-mpnet-base-v2']
for i, md in tqdm(enumerate(lst_models_3)):
    params_ = extract_pars(params_for_models[i])
    sentence_model = SentenceTransformer(md, device="cuda")
    umap_model = umap.UMAP(**params_[0], random_state=42)
    hdbscan_model = hdbscan.HDBSCAN(**params_[1])
    topic_model = BERTopic(embedding_model=sentence_model, umap_model=umap_model, hdbscan_model=hdbscan_model, **params_[2])
    topics = topic_model.fit_transform(np.array(data_test))
    scores_paramed.append(compute_metrics(topics, topic_model, np.array(data_test)))
print(scores_paramed)
# Out:
# 0it [00:00, ?it/s]
# [(0.9153846153846154, 0.1635431657215938, 0.7149958402605795), (0.8578947368421053, 0.13978068583345116, 0.6686617369147273), (0.8555555555555555, 0.15337788179734224, 0.6919941448233904), (0.8631578947368421, 0.13549285052236973, 0.7085891360388634), (0.8571428571428571, 0.1573613540241867, 0.6823278178506873)]

# %%
scores_trained.append((None, None, None))

# %%
lst_models_3 = ['model_w/tsdae-declutr-base', 'model_w/tsdae-electra-base-discriminator',
                'model_w/tsdae-all-distilroberta-v1', 'model_w/tsdae-BiomedNLP-PubMedBERT-base-uncased-abstract',
                'kek/all-mpnet-base-v2']
tmp = list(zip([x.split('/')[1] + ' untrained' for x in lst_models_3], scores_untrained)) + list(zip([x.split('/')[1] +
' trained'for x in lst_models_3], scores_trained)) + list(zip([x.split('/')[1] + ' params' for x in lst_models_3], scores_paramed))

# %%
tmp
# Out:
# [('tsdae-declutr-base untrained',
#   (0.8216867469879519, 0.1491818372449558, 0.6768210967742299)),
#  ('tsdae-electra-base-discriminator untrained',
#   (0.8371681415929203, -0.1863928028104267, 0.3271564661763955)),
#  ('tsdae-all-distilroberta-v1 untrained',
#   (0.8012578616352202, 0.1649150506281666, 0.6895854913749707)),
#  ('tsdae-BiomedNLP-PubMedBERT-base-uncased-abstract untrained',
#   (0.781578947368421, 0.12828512277294654, 0.6679900561014893)),
#  ('all-mpnet-base-v2 untrained',
#   (0.8241758241758241, 0.17764859323812446, 0.700082176733079)),
#  ('tsdae-declutr-base trained',
#   (0.8189189189189189, 0.16313223258919463, 0.695366367610592)),
#  ('tsdae-electra-base-discriminator trained',
#   (1.0, -0.03706645614338682, 0.449954260949123)),
#  ('tsdae-all-distilroberta-v1 trained',
#   (1.0, 0.06886228904641256, 0.4568813321059566)),
#  ('tsdae-BiomedNLP-PubMedBERT-base-uncased-abstract trained',
#   (0.8166666666666667, 0.14485702070906367, 0.6903788020275959)),
#  ('all-mpnet-base-v2 trained', (None, None, None)),
#  ('tsdae-declutr-base params',
#   (0.9153846153846154, 0.1635431657215938, 0.7149958402605795)),
#  ('tsdae-electra-base-discriminator params',
#   (0.8578947368421053, 0.13978068583345116, 0.6686617369147273)),
#  ('tsdae-all-distilroberta-v1 params',
#   (0.8555555555555555, 0.15337788179734224, 0.6919941448233904)),
#  ('tsdae-BiomedNLP-PubMedBERT-base-uncased-abstract params',
#   (0.8631578947368421, 0.13549285052236973, 0.7085891360388634)),
#  ('all-mpnet-base-v2 params',
#   (0.8571428571428571, 0.1573613540241867, 0.6823278178506873))]

# %%
dct = dict(tmp)
results = pd.DataFrame(dct)
results.index = ['topic diversity score', 'npmi score', 'cv score']
results.T.sort_index().to_csv('results_my.csv')

# %%
results.T.sort_index()
# Out:
#                                                    topic diversity score  \
# all-mpnet-base-v2 params                                        0.857143
# all-mpnet-base-v2 trained                                           None
# all-mpnet-base-v2 untrained                                     0.824176
# tsdae-BiomedNLP-PubMedBERT-base-uncased-abstrac...              0.863158
# tsdae-BiomedNLP-PubMedBERT-base-uncased-abstrac...              0.816667
# tsdae-BiomedNLP-PubMedBERT-base-uncased-abstrac...              0.781579
# tsdae-all-distilroberta-v1 params                               0.855556
# tsdae-all-distilroberta-v1 trained                                   1.0
# tsdae-all-distilroberta-v1 untrained                            0.801258
# tsdae-declutr-base params                                       0.915385
# tsdae-declutr-base trained                                      0.818919
# tsdae-declutr-base untrained                                    0.821687
# tsdae-electra-base-discriminator params                         0.857895
# tsdae-electra-base-discriminator trained                             1.0
# tsdae-electra-base-discriminator untrained                      0.837168
#
#                                                    npmi score  cv score
# all-mpnet-base-v2 params                             0.157361  0.682328
# all-mpnet-base-v2 trained                                None      None
# all-mpnet-base-v2 untrained                          0.177649  0.700082
# tsdae-BiomedNLP-PubMedBERT-base-uncased-abstrac...   0.135493  0.708589
# tsdae-BiomedNLP-PubMedBERT-base-uncased-abstrac...   0.144857  0.690379
# tsdae-BiomedNLP-PubMedBERT-base-uncased-abstrac...   0.128285   0.66799
# tsdae-all-distilroberta-v1 params                    0.153378  0.691994
# tsdae-all-distilroberta-v1 trained                   0.068862  0.456881
# tsdae-all-distilroberta-v1 untrained                 0.164915  0.689585
# tsdae-declutr-base params                            0.163543  0.714996
# tsdae-declutr-base trained                           0.163132  0.695366
# tsdae-declutr-base untrained                         0.149182  0.676821
# tsdae-electra-base-discriminator params              0.139781  0.668662
# tsdae-electra-base-discriminator trained            -0.037066  0.449954
# tsdae-electra-base-discriminator untrained          -0.186393  0.327156

# %%
# https://towardsdatascience.com/evaluate-topic-model-in-python-latent-dirichlet-allocation-lda-7d57484bb5d0
